# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
y = np.array([35,25,25,13])
lable = ['Apple','Banana','Cherry','Dates']
exp = [0.2,0,0,0]
plt.pie(y,labels=lable,explode=exp,shadow=True)
plt.legend(title='Four Fruits : ')
plt.show()
