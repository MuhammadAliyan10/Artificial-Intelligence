# %%
import numpy as np
import pandas as pd
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
np.random.seed(42)
data = np.random.rand(100, 2)

# %%
df = pd.DataFrame(data, columns=['Feature1', 'Feature2'])
df.head()
# Out:
#    Feature1  Feature2
# 0  0.374540  0.950714
# 1  0.731994  0.598658
# 2  0.156019  0.155995
# 3  0.058084  0.866176
# 4  0.601115  0.708073

# %%
kmeans = KMeans(n_clusters=3, random_state=42)  # We want 3 clusters
kmeans.fit(df)
# Out:
# KMeans(n_clusters=3, random_state=42)

# %%
df['Cluster'] = kmeans.labels_

# %%
plt.scatter(df['Feature1'], df['Feature2'], c=df['Cluster'], cmap='viridis')
plt.title('K-Means Clustering Example')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.show()

# %%
print("Sample data with cluster labels:")
print(df.head())
# Out:
# Sample data with cluster labels:
#    Feature1  Feature2  Cluster
# 0  0.374540  0.950714        2
# 1  0.731994  0.598658        0
# 2  0.156019  0.155995        1
# 3  0.058084  0.866176        2
# 4  0.601115  0.708073        0
