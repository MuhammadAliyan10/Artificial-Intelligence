# %%
import pandas as pd
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
df = pd.DataFrame(iris.data,columns=iris.feature_names)

# %%
df['target'] = iris.target

# %%
df.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#    target
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0

# %%
df.tail()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 145       2
# 146       2
# 147       2
# 148       2
# 149       2

# %%
df['flower_names'] = df.target.apply(lambda x: iris.target_names[x])

# %%
df.head(60)
# Out:
#     sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                 5.1               3.5                1.4               0.2
# 1                 4.9               3.0                1.4               0.2
# 2                 4.7               3.2                1.3               0.2
# 3                 4.6               3.1                1.5               0.2
# 4                 5.0               3.6                1.4               0.2
# 5                 5.4               3.9                1.7               0.4
# 6                 4.6               3.4                1.4               0.3
# 7                 5.0               3.4                1.5               0.2
# 8                 4.4               2.9                1.4               0.2
# 9                 4.9               3.1                1.5               0.1
# 10                5.4               3.7                1.5               0.2
# 11                4.8               3.4                1.6               0.2
# 12                4.8               3.0                1.4               0.1
# 13                4.3               3.0                1.1               0.1
# 14                5.8               4.0                1.2               0.2
# 15                5.7               4.4                1.5               0.4
# 16                5.4               3.9                1.3               0.4
# 17                5.1               3.5                1.4               0.3
# 18                5.7               3.8                1.7               0.3
# 19                5.1               3.8                1.5               0.3
# 20                5.4               3.4                1.7               0.2
# 21                5.1               3.7                1.5               0.4
# 22                4.6               3.6                1.0               0.2
# 23                5.1               3.3                1.7               0.5
# 24                4.8               3.4                1.9               0.2
# 25                5.0               3.0                1.6               0.2
# 26                5.0               3.4                1.6               0.4
# 27                5.2               3.5                1.5               0.2
# 28                5.2               3.4                1.4               0.2
# 29                4.7               3.2                1.6               0.2
# 30                4.8               3.1                1.6               0.2
# 31                5.4               3.4                1.5               0.4
# 32                5.2               4.1                1.5               0.1
# 33                5.5               4.2                1.4               0.2
# 34                4.9               3.1                1.5               0.2
# 35                5.0               3.2                1.2               0.2
# 36                5.5               3.5                1.3               0.2
# 37                4.9               3.6                1.4               0.1
# 38                4.4               3.0                1.3               0.2
# 39                5.1               3.4                1.5               0.2
# 40                5.0               3.5                1.3               0.3
# 41                4.5               2.3                1.3               0.3
# 42                4.4               3.2                1.3               0.2
# 43                5.0               3.5                1.6               0.6
# 44                5.1               3.8                1.9               0.4
# 45                4.8               3.0                1.4               0.3
# 46                5.1               3.8                1.6               0.2
# 47                4.6               3.2                1.4               0.2
# 48                5.3               3.7                1.5               0.2
# 49                5.0               3.3                1.4               0.2
# 50                7.0               3.2                4.7               1.4
# 51                6.4               3.2                4.5               1.5
# 52                6.9               3.1                4.9               1.5
# 53                5.5               2.3                4.0               1.3
# 54                6.5               2.8                4.6               1.5
# 55                5.7               2.8                4.5               1.3
# 56                6.3               3.3                4.7               1.6
# 57                4.9               2.4                3.3               1.0
# 58                6.6               2.9                4.6               1.3
# 59                5.2               2.7                3.9               1.4
#
#     target flower_names
# 0        0       setosa
# 1        0       setosa
# 2        0       setosa
# 3        0       setosa
# 4        0       setosa
# 5        0       setosa
# 6        0       setosa
# 7        0       setosa
# 8        0       setosa
# 9        0       setosa
# 10       0       setosa
# 11       0       setosa
# 12       0       setosa
# 13       0       setosa
# 14       0       setosa
# 15       0       setosa
# 16       0       setosa
# 17       0       setosa
# 18       0       setosa
# 19       0       setosa
# 20       0       setosa
# 21       0       setosa
# 22       0       setosa
# 23       0       setosa
# 24       0       setosa
# 25       0       setosa
# 26       0       setosa
# 27       0       setosa
# 28       0       setosa
# 29       0       setosa
# 30       0       setosa
# 31       0       setosa
# 32       0       setosa
# 33       0       setosa
# 34       0       setosa
# 35       0       setosa
# 36       0       setosa
# 37       0       setosa
# 38       0       setosa
# 39       0       setosa
# 40       0       setosa
# 41       0       setosa
# 42       0       setosa
# 43       0       setosa
# 44       0       setosa
# 45       0       setosa
# 46       0       setosa
# 47       0       setosa
# 48       0       setosa
# 49       0       setosa
# 50       1   versicolor
# 51       1   versicolor
# 52       1   versicolor
# 53       1   versicolor
# 54       1   versicolor
# 55       1   versicolor
# 56       1   versicolor
# 57       1   versicolor
# 58       1   versicolor
# 59       1   versicolor

# %%
df0 =df[df.target == 0] 
df1 =df[df.target == 1] 
df2 =df[df.target == 2]

# %%
df2.head()
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 100                6.3               3.3                6.0               2.5
# 101                5.8               2.7                5.1               1.9
# 102                7.1               3.0                5.9               2.1
# 103                6.3               2.9                5.6               1.8
# 104                6.5               3.0                5.8               2.2
#
#      target flower_names
# 100       2    virginica
# 101       2    virginica
# 102       2    virginica
# 103       2    virginica
# 104       2    virginica

# %%
from matplotlib import pyplot as plt
plt.xlabel('sepal Length')
plt.ylabel('sepal Width')
plt.scatter(df0['sepal length (cm)'],df0['sepal width (cm)'],color='red',marker='+')
plt.scatter(df1['sepal length (cm)'],df1['sepal width (cm)'],color='blue',marker='+')
plt.scatter(df2['sepal length (cm)'],df2['sepal width (cm)'],color='black',marker='+')

# %%
plt.xlabel('petal Length')
plt.ylabel('petal Width')
plt.scatter(df0['petal length (cm)'],df0['petal width (cm)'],color='red',marker='+')
plt.scatter(df1['petal length (cm)'],df1['petal width (cm)'],color='blue',marker='+')
plt.scatter(df2['petal length (cm)'],df2['petal width (cm)'],color='black',marker='+')

# %%
x = df.drop(columns=['target','flower_names'],axis='columns')
y = df['target']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

# %%
from sklearn.svm import SVC

# %%
model = SVC()

# %%
model.fit(x_train,y_train)
# Out:
# SVC()

# %%
model.score(x_test,y_test)
# Out:
# 0.9666666666666667

# %%
iris.data[95]
# Out:
# array([5.7, 3. , 4.2, 1.2])

# %%
model.predict([[6.7, 3.3, 5.7, 2.1]])
# Out:
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
# array([2])

# %%
def flowerNameFinder(x1,x2,x3,x4):
    x = model.predict([[x1,x2,x3,x4]])
    x = x[0]
    if x == 0:
        print("The flower is setosa.")
    elif x ==2:
        print("The flower is virginica.")
    else:
        print("The flower is virginica.")

# %%
flowerNameFinder(5.7, 3. , 4.2, 1.2)
# Out:
# The flower is virginica
# c:\Users\HP\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:465: UserWarning: X does not have valid feature names, but SVC was fitted with feature names
#   warnings.warn(
